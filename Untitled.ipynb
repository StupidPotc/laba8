# %%
import pandas as pd

# %%
states_dataset=pd.read_csv("livingwage50states.csv")

# %%
states_dataset
# Out:
#          state_territory  population_2020  land_area_sqmi  population_density  \
# 0                Alabama          5024279        50645.33               99.21
# 1                 Alaska           733391       570640.95                1.29
# 2                Arizona          7151502       113594.08               62.96
# 3               Arkansas          3011524        52035.48               57.87
# 4             California         39538223       155779.22              253.81
# 5               Colorado          5773714       103641.89               55.71
# 6            Connecticut          3605944         4842.36              744.67
# 7               Delaware           989948         1948.54              508.05
# 8   District of Columbia           689545           61.05            11294.76
# 9                Florida         21538187        53624.76              401.65
# 10               Georgia         10711908        57513.49              186.25
# ...

# %%
states_dataset.shape
# Out:
# (51, 16)

# %%
states_dataset.columns
# Out:
# Index(['state_territory', 'population_2020', 'land_area_sqmi',
#        'population_density', 'oneadult_nokids', 'oneadult_onekid',
#        'oneadult_twokids', 'oneadult_threekids', 'twoadults_oneworking_nokids',
#        'twoadults_oneworking_onekid', 'twoadults_oneworking_twokids',
#        'twoadults_oneworking_threekids', 'twoadults_bothworking_nokids',
#        'twoadults_bothworking_onekid', 'twoadults_bothworking_twokids',
#        'twoadults_bothworking_threekids'],
#       dtype='object')

# %%
states_dataset[['state_territory', 'population_2020']].head()
# Out:
#   state_territory  population_2020
# 0         Alabama          5024279
# 1          Alaska           733391
# 2         Arizona          7151502
# 3        Arkansas          3011524
# 4      California         39538223

# %%
states_dataset.loc[1:3]
# Out:
#   state_territory  population_2020  land_area_sqmi  population_density  \
# 1          Alaska           733391       570640.95                1.29
# 2         Arizona          7151502       113594.08               62.96
# 3        Arkansas          3011524        52035.48               57.87
#
#    oneadult_nokids  oneadult_onekid  oneadult_twokids  oneadult_threekids  \
# 1            15.06            29.86             37.09               48.86
# 2            14.94            29.01             35.11               45.59
# 3            13.29            28.23             34.85               44.48
#
#    twoadults_oneworking_nokids  twoadults_oneworking_onekid  \
# 1                        23.38                        28.12
# 2                        24.30                        28.69
# 3                        22.50                        27.15
#
#    twoadults_oneworking_twokids  twoadults_oneworking_threekids  \
# 1                         31.66                           35.57
# ...

# %%
states_dataset[states_dataset.oneadult_onekid == 27.06].head()
# Out:
#    state_territory  population_2020  land_area_sqmi  population_density  \
# 0          Alabama          5024279        50645.33               99.21
# 41    South Dakota           886667        74811.00               11.85
#
#     oneadult_nokids  oneadult_onekid  oneadult_twokids  oneadult_threekids  \
# 0             13.77            27.06             33.09               42.01
# 41            12.61            27.06             33.49               42.83
#
#     twoadults_oneworking_nokids  twoadults_oneworking_onekid  \
# 0                          22.3                        26.44
# 41                         21.3                        25.74
#
#     twoadults_oneworking_twokids  twoadults_oneworking_threekids  \
# 0                          30.04                           31.99
# 41                         29.19                           31.17
#
#     twoadults_bothworking_nokids  twoadults_bothworking_onekid  \
# 0                          11.15                         14.92
# ...

# %%
# %matplotlib inline

# %%
states_dataset.population_2020.hist()
# Out:
# <AxesSubplot:>
