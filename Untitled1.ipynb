# %%
import pandas as pd
import re

# %%
dataset=pd.read_csv("city.csv")

# %%
dataset
# Out:
#                          address  postal_code country federal_district  \
# 0        Респ Адыгея, г Адыгейск     385200.0  Россия            Южный
# 1                       г Майкоп     385000.0  Россия            Южный
# 2                г Горно-Алтайск     649000.0  Россия        Сибирский
# 3       Алтайский край, г Алейск     658125.0  Россия        Сибирский
# 4                      г Барнаул     656000.0  Россия        Сибирский
# ...                          ...          ...     ...              ...
# 1112   Ярославская обл, г Ростов     152150.0  Россия      Центральный
# 1113  Ярославская обл, г Рыбинск     152900.0  Россия      Центральный
# 1114   Ярославская обл, г Тутаев     152300.0  Россия      Центральный
# 1115    Ярославская обл, г Углич     152610.0  Россия      Центральный
# 1116                 г Ярославль     150000.0  Россия      Центральный
#
#      region_type       region area_type        area city_type           city  \
# ...

# %%
dataset.count()
# Out:
# address             1117
# postal_code         1116
# country             1117
# federal_district    1117
# region_type         1117
# region              1117
# area_type            612
# area                 612
# city_type           1113
# city                1113
# settlement_type        2
# settlement             2
# kladr_id            1117
# fias_id             1117
# fias_level          1117
# capital_marker      1117
# okato               1117
# oktmo               1117
# tax_office          1117
# timezone            1117
# geo_lat             1117
# geo_lon             1117
# population          1117
# foundation_year     1117
# dtype: int64

# %%
dataset=dataset['federal_district'].value_counts().rename_axis('federal_district').reset_index(name='city_counts')

# %%
dataset= DataFrame({'count' : dataset.groupby( ["federal_district", "federal_district", "federal_district"] ).size()}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b764c5e5eee1> in <module>
# ----> 1 dataset= DataFrame({'count' : dataset.groupby( ["federal_district", "federal_district", "federal_district"] ).size()}).reset_index()
#
# NameError: name 'DataFrame' is not defined

# %%
dataset.loc[:,'federal_district':'region_type']
# Out:
#      federal_district region_type
# 0               Южный        Респ
# 1               Южный        Респ
# 2           Сибирский        Респ
# 3           Сибирский        край
# 4           Сибирский        край
# ...               ...         ...
# 1112      Центральный         обл
# 1113      Центральный         обл
# 1114      Центральный         обл
# 1115      Центральный         обл
# 1116      Центральный         обл
#
# [1117 rows x 2 columns]

# %%
df_marks = pd.DataFrame(dataset)
type(grouped_by_city)
pandas.core.groupby.generic.DataFrameGroupBy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-49cfe86a05d6> in <module>
#       1 df_marks = pd.DataFrame(dataset)
# ----> 2 type(grouped_by_city)
#       3 pandas.core.groupby.generic.DataFrameGroupBy
#
# NameError: name 'grouped_by_city' is not defined

# %%
grouped_by_federal_district.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f6999f24b899> in <module>
# ----> 1 grouped_by_federal_district.count()
#
# NameError: name 'grouped_by_federal_district' is not defined

# %%
dataset.count()
# Out:
# address             1117
# postal_code         1116
# country             1117
# federal_district    1117
# region_type         1117
# region              1117
# area_type            612
# area                 612
# city_type           1113
# city                1113
# settlement_type        2
# settlement             2
# kladr_id            1117
# fias_id             1117
# fias_level          1117
# capital_marker      1117
# okato               1117
# oktmo               1117
# tax_office          1117
# timezone            1117
# geo_lat             1117
# geo_lon             1117
# population          1117
# foundation_year     1117
# dtype: int64

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame("city.csv")
counterFunc = df.apply(
    lambda x: True if x[1] > 3 else False , axis=1)
numOfRows = len(counterFunc[counterFunc == True].index)
print(df)
print('Row count > 3 in column[1]is:',numOfRows)
